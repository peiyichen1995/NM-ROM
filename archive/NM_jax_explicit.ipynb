# %%
import jax.numpy as jnp
import numpy as np

import jax
from jax import nn as jnn
from jax import random

from flax import linen as nn
from flax import optim

import optax

import h5py
from fenics import *

from typing import Sequence

import matplotlib.pyplot as plt

import basix
from basix import ElementFamily, CellType, LagrangeVariant

from scipy.integrate import solve_ivp

# again, this only works on startup!
from jax.config import config
config.update("jax_enable_x64", True)
# Out:
# 2022-03-18 16:53:24.997846: W external/org_tensorflow/tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-18 16:53:25.110608: W external/org_tensorflow/tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-18 16:53:25.118051: W external/org_tensorflow/tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).

# %%
def read_mesh_and_function(file_name, var_name):

    # Open solution file
    infile = XDMFFile(file_name + ".xdmf")
    infile_h5 = h5py.File(file_name + ".h5", "r")
    t_steps = len(infile_h5[var_name].keys())

    # Read in mesh
    mesh = Mesh()
    infile.read(mesh)

    # Read function
    V = FunctionSpace(mesh, "CG", 1)
    u = Function(V)
    solution = np.zeros((V.dim(), t_steps))
    for i in range(t_steps):
        infile.read_checkpoint(u, var_name, i - t_steps + 1)
        solution[:, i] = u.vector().get_local()

    # Clean up
    infile.close()
    infile_h5.close()

    return mesh, solution
    
nu = 0.1
A = 0.5
mesh, u_ref = read_mesh_and_function("output/burgers_1D/nu_"+str(nu)+"/FOM", "u")
u_ref = u_ref.T

# %%
time_steps, N = u_ref.shape
u_train = u_ref[np.arange(0,time_steps,10)]
n = 15
M1 = 50
M2 = 50
n_epoch = 5000

# %%
class Encoder(nn.Module):
    latents: Sequence[int]
    
    @nn.compact
    def __call__(self, x):
        x = nn.Dense(self.latents[0],dtype=jnp.float64,param_dtype=jnp.float64)(x)
        x = nn.swish(x)
        xr = nn.Dense(self.latents[1],dtype=jnp.float64,param_dtype=jnp.float64)(x)
        return xr

# %%
def gaussian_kernel(window_size, sigma):
    mu = window_size / 2
    x = jnp.arange(window_size)
    window = jnp.exp((-((x-mu)**2))/(2*sigma**2))/sigma/jnp.sqrt(2*jnp.pi)
    return window

class Decoder(nn.Module):
    latents: Sequence[int]
    
    @nn.compact
    def __call__(self, x):
        x = nn.Dense(self.latents[0],dtype=jnp.float64,param_dtype=jnp.float64)(x)
        x = nn.swish(x)
        x = nn.Dense(self.latents[1],dtype=jnp.float64,param_dtype=jnp.float64)(x)
        
        window_size = len(x)
        sigma = window_size / 2 / 6
        window = gaussian_kernel(window_size, sigma)
        x = jnp.convolve(x, window, mode='same')
        return x

# %%
class VAE(nn.Module):
    encoder_latents: Sequence[int]
    decoder_latents: Sequence[int]

    def setup(self):
        self.encoder = Encoder(self.encoder_latents)
        self.decoder = Decoder(self.decoder_latents)
    
    def encode(self, x):
        return self.encoder(x)

    def decode(self, x):
        return self.decoder(x)

    def __call__(self, x):
        return self.decode(self.encode(x))

def model():
    return VAE(encoder_latents=[M1,n],decoder_latents=[M2,N])

# %%
@jax.jit
def loss_fn(params, x):
    xt = jax.vmap(model().apply, in_axes=(None, 0))(params, x)
    errors = jax.vmap(rel_err, in_axes=(0,0), out_axes=0)(x,xt)
    l = jnp.sum(errors**2)/time_steps
    return l

def rel_err(x, xt):
    return jnp.linalg.norm(x-xt)

params = model().init(random.PRNGKey(0), u_train[0])
tx = optax.adam(0.001)
opt_state = tx.init(params)
loss_grad_fn = jax.value_and_grad(loss_fn)
# Out:
# 2022-03-18 16:53:28.160864: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
for i in range(n_epoch):
    loss_val, grads = loss_grad_fn(params, u_train)
    updates, opt_state = tx.update(grads, opt_state)
    params = optax.apply_updates(params, updates)
    if i % 10 == 0:
        print('Loss step {}: '.format(i), loss_val)
    if loss_val < 1e-6:
        break
# Out:
# Loss step 0:  164.07086630903623
# Loss step 10:  16.448741125909788
# Loss step 20:  5.293638211248935
# Loss step 30:  3.3108188515000663
# Loss step 40:  3.0219110871619503
# Loss step 50:  2.281090225968992
# Loss step 60:  1.7132980658482182
# Loss step 70:  1.1835943487806566
# Loss step 80:  0.772127017756558
# Loss step 90:  0.6336601444706954
# Loss step 100:  0.557620652702314
# Loss step 110:  0.523726704263627
# Loss step 120:  0.5122388861284498
# Loss step 130:  0.4998932674257034
# Loss step 140:  0.48887973183443384
# Loss step 150:  0.47837127536132773
# Loss step 160:  0.4676388571084694
# Loss step 170:  0.45606291641479557
# Loss step 180:  0.44359510613028535
# Loss step 190:  0.4301607772582001
# Loss step 200:  0.4156382556469609
# Loss step 210:  0.39987601328227995
# Loss step 220:  0.38271791114268605
# Loss step 230:  0.3640618781867224
# Loss step 240:  0.3439231913489212
# Loss step 250:  0.3224859811076554
# Loss step 260:  0.3001293022708123
# Loss step 270:  0.27741155567072423
# Loss step 280:  0.2550070248132485
# Loss step 290:  0.23360388888600564
# Loss step 300:  0.21379038261050862
# Loss step 310:  0.19596518031048807
# Loss step 320:  0.18029822428803025
# Loss step 330:  0.16674811610507215
# Loss step 340:  0.15512306363096134
# Loss step 350:  0.14515977132320385
# Loss step 360:  0.13659184276462286
# Loss step 370:  0.1291894018401745
# Loss step 380:  0.12276907777458544
# Loss step 390:  0.11718605667342409
# Loss step 400:  0.11232144505976377
# Loss step 410:  0.10807262179274169
# Loss step 420:  0.10434826715974702
# Loss step 430:  0.10106668973393439
# Loss step 440:  0.09815560216814125
# Loss step 450:  0.09555213277167823
# Loss step 460:  0.09320256592935774
# Loss step 470:  0.09106173342196841
# Loss step 480:  0.08909215357590974
# Loss step 490:  0.08726304837823315
# Loss step 500:  0.08554934519150892
# Loss step 510:  0.08393073287985511
# Loss step 520:  0.08239080939164278
# Loss step 530:  0.08091633446184528
# Loss step 540:  0.07949658765402741
# Loss step 550:  0.07812282671469448
# Loss step 560:  0.07678784086344749
# Loss step 570:  0.07548559443816225
# Loss step 580:  0.0742109556310749
# Loss step 590:  0.07295950234316013
# Loss step 600:  0.07172739357086935
# Loss step 610:  0.07051129180175687
# Loss step 620:  0.0693083207268393
# Loss step 630:  0.06811604349509488
# Loss step 640:  0.06693244939001224
# Loss step 650:  0.06575594042544196
# Loss step 4670:  0.0035646965223282193
# Loss step 4680:  0.0035536581279124353
# Loss step 4690:  0.0035438123521824914
# Loss step 4700:  0.0036638460771723173
# Loss step 4710:  0.03560851709143281
# Loss step 4720:  0.04138547706166254
# Loss step 4730:  0.028186928572535085
# Loss step 4740:  0.020537778766495943
# Loss step 4750:  0.00470796327842967
# Loss step 4760:  0.005713382119193225
# Loss step 4770:  0.0037211070688286454
# Loss step 4780:  0.0039050223753665154
# Loss step 4790:  0.003610011888430407
# Loss step 4800:  0.0035951782193795615
# Loss step 4810:  0.003571505342825164
# Loss step 4820:  0.0035465755831514695
# Loss step 4830:  0.00352817476830863
# Loss step 4840:  0.003513015410168524
# Loss step 4850:  0.003498918987607328
# Loss step 4860:  0.003485434688362287
# Loss step 4870:  0.003472483558306606
# Loss step 4880:  0.0034599948192415076
# Loss step 4890:  0.0034479107205133436
# Loss step 4900:  0.0034361840222735295
# Loss step 4910:  0.003424795863312292
# Loss step 4920:  0.0034147393047337118
# Loss step 4930:  0.0035197112001700602
# Loss step 4940:  0.027862500571919916
# Loss step 4950:  0.034274982377797136
# Loss step 4960:  0.03372242435470475
# Loss step 4970:  0.006018700921970301
# Loss step 4980:  0.005195117579034856
# Loss step 4990:  0.0045297545325766585

# %%
u_ref_encoded = model().apply(params, u_ref[0], method=VAE.encode)
Phi = jax.jacfwd(model().apply, argnums=1)(params, u_ref_encoded, method=VAE.decode)
plt.plot(Phi.T[10])

# %%
plt.plot(u_ref[400])
plt.plot(model().apply(params, u_ref[400]))

# %%
t_start = 0.0
t_final = 0.15
t_steps = 500
t_sequence = np.linspace(t_start, t_final, t_steps + 1)
dt = (t_final - t_start) / t_steps

V = FunctionSpace(mesh, "CG", 1)
u = Function(V)
v = TestFunction(V)

M_form = derivative(dot(u, v) * dx, u)
M = assemble(M_form).array()
M_inv = np.linalg.inv(M)

rhs_form = (- inner(nu * grad(u), grad(v)) - inner(u.dx(0) * u, v)) * dx

# %%
jacobian = jax.jacobian(model().apply, argnums=1)

# %%
def rhs(ur, params):
    ut = model().apply(params, ur, method=VAE.decode)
    u.vector().set_local(ut)
    r = assemble(rhs_form).get_local()
    rhs_vec = np.matmul(M_inv, r)
    J = jacobian(params, ur, method=VAE.decode)
    Jinv = jnp.linalg.pinv(J)
    rhs_vec_r = np.matmul(Jinv, rhs_vec)
    return rhs_vec_r

def rhs_helper(t, y):
    print('t = {:}'.format(t))
    return rhs(y, params)

# %%
u0 = Function(V)
u0_expr = Expression(
    "x[0] < 1 ? 1+A*(sin(2*pi*x[0]-pi/2)+1) : 1", degree=1, A=A)
u0.interpolate(u0_expr)

ur0 = model().apply(params, u0.vector().get_local(), method=VAE.encode)

urs = solve_ivp(rhs_helper, (t_start, t_final), ur0, t_eval=t_sequence, method='RK45')
# Out:
# t = 0.0
# t = 6.02751694867092e-07
# t = 1.2055033897341842e-05
# t = 1.808255084601276e-05
# t = 4.8220135589367366e-05
# t = 5.3577928432630396e-05
# t = 6.02751694867092e-05
# t = 6.02751694867092e-05
# t = 5.402926438819955e-06
# t = 8.104389658229932e-06
# t = 2.161170575527982e-05
# t = 2.4013006394755353e-05
# t = 2.7014632194099773e-05
# t = 2.7014632194099773e-05
# t = 3.191519744118929e-06
# t = 4.787279616178393e-06
# t = 1.2766078976475715e-05
# t = 1.4184532196084128e-05
# t = 1.5957598720594644e-05
# t = 1.5957598720594644e-05
# t = 2.6945228787694472e-06
# t = 4.04178431815417e-06
# t = 1.0778091515077789e-05
# t = 1.197565723897532e-05
# t = 1.3472614393847236e-05
# t = 1.3472614393847236e-05
# t = 1.6055728752763174e-05
# t = 1.7347285932221143e-05
# t = 2.3805071829510987e-05
# t = 2.4953122655695848e-05
# t = 2.6388186188426925e-05
# t = 2.6388186188426925e-05
# t = 1.5524543346748134e-05
# t = 1.6550507823198585e-05
# t = 2.168033020545083e-05
# t = 2.259229862896234e-05
# t = 2.373225915835173e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/gary/projects/pod_burger/NM_jax_explicit.ipynb Cell 14' in <cell line: 8>()
#       <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000013?line=3'>4</a> u0.interpolate(u0_expr)
#       <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000013?line=5'>6</a> ur0 = model().apply(params, u0.vector().get_local(), method=VAE.encode)
# ----> <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000013?line=7'>8</a> urs = solve_ivp(rhs_helper, (t_start, t_final), ur0, t_eval=t_sequence, method='RK45')
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/ivp.py:580, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/ivp.py?line=577'>578</a> status = None
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/ivp.py?line=578'>579</a> while status is None:
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/ivp.py?line=579'>580</a>     message = solver.step()
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/ivp.py?line=581'>582</a>     if solver.status == 'finished':
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/ivp.py?line=582'>583</a>         status = 0
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py:181, in OdeSolver.step(self)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py?line=178'>179</a> else:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py?line=179'>180</a>     t = self.t
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py?line=180'>181</a>     success, message = self._step_impl()
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py?line=182'>183</a>     if not success:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py?line=183'>184</a>         self.status = 'failed'
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py:144, in RungeKutta._step_impl(self)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py?line=140'>141</a> h = t_new - t
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py?line=141'>142</a> h_abs = np.abs(h)
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py?line=143'>144</a> y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py?line=144'>145</a>                        self.B, self.C, self.K)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py?line=145'>146</a> scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py?line=146'>147</a> error_norm = self._estimate_error_norm(self.K, h, scale)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py:64, in rk_step(fun, t, y, f, h, A, B, C, K)
#      <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py?line=61'>62</a> for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py?line=62'>63</a>     dy = np.dot(K[:s].T, a[:s]) * h
# ---> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py?line=63'>64</a>     K[s] = fun(t + c * h, y + dy)
#      <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py?line=65'>66</a> y_new = y + h * np.dot(K[:-1].T, B)
#      <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py?line=66'>67</a> f_new = fun(t + h, y_new)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py:138, in OdeSolver.__init__.<locals>.fun(t, y)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py?line=135'>136</a> def fun(t, y):
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py?line=136'>137</a>     self.nfev += 1
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py?line=137'>138</a>     return self.fun_single(t, y)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py:20, in check_arguments.<locals>.fun_wrapped(t, y)
#      <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py?line=18'>19</a> def fun_wrapped(t, y):
# ---> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py?line=19'>20</a>     return np.asarray(fun(t, y), dtype=dtype)
#
# /home/gary/projects/pod_burger/NM_jax_explicit.ipynb Cell 13' in rhs_helper(t, y)
#      <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000012?line=10'>11</a> def rhs_helper(t, y):
#      <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000012?line=11'>12</a>     print('t = {:}'.format(t))
# ---> <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000012?line=12'>13</a>     return rhs(y, params)
#
# /home/gary/projects/pod_burger/NM_jax_explicit.ipynb Cell 13' in rhs(ur, params)
#       <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000012?line=3'>4</a> r = assemble(rhs_form).get_local()
#       <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000012?line=4'>5</a> rhs_vec = np.matmul(M_inv, r)
# ----> <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000012?line=5'>6</a> J = jacobian(params, ur, method=VAE.decode)
#       <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000012?line=6'>7</a> Jinv = jnp.linalg.pinv(J)
#       <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000012?line=7'>8</a> rhs_vec_r = np.matmul(Jinv, rhs_vec)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py:1254, in jacrev.<locals>.jacfun(*args, **kwargs)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=1251'>1252</a> tree_map(partial(_check_input_dtype_jacrev, holomorphic, allow_int), dyn_args)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=1252'>1253</a> if not has_aux:
# -> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=1253'>1254</a>   y, pullback = _vjp(f_partial, *dyn_args)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=1254'>1255</a> else:
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=1255'>1256</a>   y, pullback, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py:2521, in _vjp(fun, has_aux, reduce_axes, *primals)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=2518'>2519</a> if not has_aux:
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=2519'>2520</a>   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=2520'>2521</a>   out_primal, out_vjp = ad.vjp(
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=2521'>2522</a>       flat_fun, primals_flat, reduce_axes=reduce_axes)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=2522'>2523</a>   out_tree = out_tree()
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=2523'>2524</a> else:
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/ad.py:116, in vjp(traceable, primals, has_aux, reduce_axes)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/ad.py?line=113'>114</a> def vjp(traceable, primals, has_aux=False, reduce_axes=()):
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/ad.py?line=114'>115</a>   if not has_aux:
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/ad.py?line=115'>116</a>     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/ad.py?line=116'>117</a>   else:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/ad.py?line=117'>118</a>     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/ad.py:103, in linearize(traceable, *primals, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/ad.py?line=100'>101</a> _, in_tree = tree_flatten(((primals, primals), {}))
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/ad.py?line=101'>102</a> jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/ad.py?line=102'>103</a> jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/ad.py?line=103'>104</a> out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/ad.py?line=104'>105</a> assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/profiler.py:206, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/profiler.py?line=202'>203</a> @wraps(func)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/profiler.py?line=203'>204</a> def wrapper(*args, **kwargs):
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/profiler.py?line=204'>205</a>   with TraceAnnotation(name, **decorator_kwargs):
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/profiler.py?line=205'>206</a>     return func(*args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/profiler.py?line=206'>207</a>   return wrapper
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:556, in trace_to_jaxpr(fun, pvals, instantiate)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=553'>554</a> with core.new_main(JaxprTrace) as main:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=554'>555</a>   fun = trace_to_subjaxpr(fun, main, instantiate)
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=555'>556</a>   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=556'>557</a>   assert not env
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=557'>558</a>   del main, fun, env
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py:166, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=162'>163</a> gen = gen_static_args = out_store = None
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=164'>165</a> try:
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=165'>166</a>   ans = self.f(*args, **dict(self.params, **kwargs))
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=166'>167</a> except:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=167'>168</a>   # Some transformations yield from inside context managers, so we have to
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=168'>169</a>   # interrupt them before reraising the exception. Otherwise they will only
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=169'>170</a>   # get garbage-collected at some later time, running their cleanup tasks
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=170'>171</a>   # only after this exception is handled, which can corrupt the global
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=171'>172</a>   # state.
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=172'>173</a>   while stack:
#
#     [... skipping hidden 1 frame]
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py:1107, in Module.apply(self, variables, rngs, method, mutable, capture_intermediates, *args, **kwargs)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=1104'>1105</a>   method = self.__call__
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=1105'>1106</a> method = _get_unbound_fn(method)
# -> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=1106'>1107</a> return apply(
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=1107'>1108</a>     method, self,
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=1108'>1109</a>     mutable=mutable, capture_intermediates=capture_intermediates
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=1109'>1110</a> )(variables, *args, **kwargs, rngs=rngs)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py:798, in apply.<locals>.wrapper(variables, rngs, *args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=791'>792</a> @functools.wraps(fn)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=792'>793</a> def wrapper(variables: VariableDict,
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=793'>794</a>             *args,
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=794'>795</a>             rngs: Optional[RNGSequences] = None,
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=795'>796</a>             **kwargs) -> Union[Any, Tuple[Any, VariableDict]]:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=796'>797</a>   with bind(variables, rngs=rngs, mutable=mutable).temporary() as root:
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=797'>798</a>     y = fn(root, *args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=798'>799</a>   if mutable is not False:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=799'>800</a>     return y, root.mutable_variables()
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py:1374, in apply.<locals>.scope_fn(scope, *args, **kwargs)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=1371'>1372</a> _context.capture_stack.append(capture_intermediates)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=1372'>1373</a> try:
# -> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=1373'>1374</a>   return fn(module.clone(parent=scope), *args, **kwargs)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=1374'>1375</a> finally:
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=1375'>1376</a>   _context.capture_stack.pop()
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py:970, in named_call.<locals>.wrapped_fn(self, *args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=966'>967</a> @functools.wraps(prewrapped_fn)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=967'>968</a> def wrapped_fn(self, *args, **kwargs):
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=968'>969</a>   if not force and not linen_module._use_named_call:
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=969'>970</a>     return prewrapped_fn(self, *args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=970'>971</a>   fn_name = class_fn.__name__
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=971'>972</a>   method_suffix = f'.{fn_name}' if fn_name != '__call__' else ''
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py:340, in wrap_method_once.<locals>.wrapped_module_method(*args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=337'>338</a> if args and isinstance(args[0], Module):
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=338'>339</a>   self, args = args[0], args[1:]
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=339'>340</a>   return self._call_wrapped_method(fun, args, kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=340'>341</a> else:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=341'>342</a>   return fun(*args, **kwargs)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py:633, in Module._call_wrapped_method(self, fun, args, kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=630'>631</a> _context.module_stack.append(self)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=631'>632</a> try:
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=632'>633</a>   y = fun(self, *args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=633'>634</a>   if _context.capture_stack:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=634'>635</a>     filter_fn = _context.capture_stack[-1]
#
# /home/gary/projects/pod_burger/NM_jax_explicit.ipynb Cell 6' in VAE.decode(self, x)
#      <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000005?line=11'>12</a> def decode(self, x):
# ---> <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000005?line=12'>13</a>     return self.decoder(x)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py:970, in named_call.<locals>.wrapped_fn(self, *args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=966'>967</a> @functools.wraps(prewrapped_fn)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=967'>968</a> def wrapped_fn(self, *args, **kwargs):
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=968'>969</a>   if not force and not linen_module._use_named_call:
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=969'>970</a>     return prewrapped_fn(self, *args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=970'>971</a>   fn_name = class_fn.__name__
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=971'>972</a>   method_suffix = f'.{fn_name}' if fn_name != '__call__' else ''
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py:340, in wrap_method_once.<locals>.wrapped_module_method(*args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=337'>338</a> if args and isinstance(args[0], Module):
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=338'>339</a>   self, args = args[0], args[1:]
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=339'>340</a>   return self._call_wrapped_method(fun, args, kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=340'>341</a> else:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=341'>342</a>   return fun(*args, **kwargs)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py:633, in Module._call_wrapped_method(self, fun, args, kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=630'>631</a> _context.module_stack.append(self)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=631'>632</a> try:
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=632'>633</a>   y = fun(self, *args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=633'>634</a>   if _context.capture_stack:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=634'>635</a>     filter_fn = _context.capture_stack[-1]
#
# /home/gary/projects/pod_burger/NM_jax_explicit.ipynb Cell 5' in Decoder.__call__(self, x)
#      <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000004?line=9'>10</a> @nn.compact
#      <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000004?line=10'>11</a> def __call__(self, x):
# ---> <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000004?line=11'>12</a>     x = nn.Dense(self.latents[0],dtype=jnp.float64,param_dtype=jnp.float64)(x)
#      <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000004?line=12'>13</a>     x = nn.swish(x)
#      <a href='vscode-notebook-cell:/home/gary/projects/pod_burger/NM_jax_explicit.ipynb#ch0000004?line=13'>14</a>     x = nn.Dense(self.latents[1],dtype=jnp.float64,param_dtype=jnp.float64)(x)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py:970, in named_call.<locals>.wrapped_fn(self, *args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=966'>967</a> @functools.wraps(prewrapped_fn)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=967'>968</a> def wrapped_fn(self, *args, **kwargs):
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=968'>969</a>   if not force and not linen_module._use_named_call:
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=969'>970</a>     return prewrapped_fn(self, *args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=970'>971</a>   fn_name = class_fn.__name__
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/transforms.py?line=971'>972</a>   method_suffix = f'.{fn_name}' if fn_name != '__call__' else ''
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py:340, in wrap_method_once.<locals>.wrapped_module_method(*args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=337'>338</a> if args and isinstance(args[0], Module):
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=338'>339</a>   self, args = args[0], args[1:]
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=339'>340</a>   return self._call_wrapped_method(fun, args, kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=340'>341</a> else:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=341'>342</a>   return fun(*args, **kwargs)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py:633, in Module._call_wrapped_method(self, fun, args, kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=630'>631</a> _context.module_stack.append(self)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=631'>632</a> try:
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=632'>633</a>   y = fun(self, *args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=633'>634</a>   if _context.capture_stack:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=634'>635</a>     filter_fn = _context.capture_stack[-1]
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py:177, in Dense.__call__(self, inputs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py?line=167'>168</a> """Applies a linear transformation to the inputs along the last dimension.
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py?line=168'>169</a>
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py?line=169'>170</a> Args:
#    (...)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py?line=173'>174</a>   The transformed input.
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py?line=174'>175</a> """
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py?line=175'>176</a> inputs = jnp.asarray(inputs, self.dtype)
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py?line=176'>177</a> kernel = self.param('kernel',
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py?line=177'>178</a>                     self.kernel_init,
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py?line=178'>179</a>                     (inputs.shape[-1], self.features),
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py?line=179'>180</a>                     self.param_dtype)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py?line=180'>181</a> kernel = jnp.asarray(kernel, self.dtype)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py?line=181'>182</a> y = lax.dot_general(inputs, kernel,
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py?line=182'>183</a>                     (((inputs.ndim - 1,), (0,)), ((), ())),
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/linear.py?line=183'>184</a>                     precision=self.precision)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py:944, in Module.param(self, name, init_fn, *init_args)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=941'>942</a> if self._name_taken(name):
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=942'>943</a>   raise errors.NameInUseError('param', name, self.__class__.__name__)
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=943'>944</a> v = self.scope.param(name, init_fn, *init_args)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=944'>945</a> self._state.children[name] = 'params'
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/linen/module.py?line=945'>946</a> return v
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py:720, in Scope.param(self, name, init_fn, *init_args)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=713'>714</a> value = self.get_variable('params', name)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=714'>715</a> # Validate that the shape of the init_fn output is the same as the shape
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=715'>716</a> # of the existing parameter. This is to make sure that the hparams set up
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=716'>717</a> # in a Flax Module match the shapes coming in during apply, and if not,
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=717'>718</a> # catch it with an error message.
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=718'>719</a> # NOTE: We could consider moving this to `self.`
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=719'>720</a> abs_value = jax.eval_shape(lambda rng: init_fn(rng, *init_args), abs_rng)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=720'>721</a> abs_value_flat = jax.tree_leaves(abs_value)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=721'>722</a> value_flat = jax.tree_leaves(value)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py:3039, in eval_shape(fun, *args, **kwargs)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=3036'>3037</a> wrapped_fun, out_tree = flatten_fun(lu.wrap_init(fun), in_tree)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=3037'>3038</a> debug_info = pe.debug_info(fun, in_tree, True, "eval_shape")
# -> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=3038'>3039</a> out = pe.abstract_eval_fun(wrapped_fun.call_wrapped,
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=3039'>3040</a>                            *map(shaped_abstractify, args_flat),
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=3040'>3041</a>                            debug_info=debug_info)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=3041'>3042</a> out = [ShapeDtypeStruct(x.shape, x.dtype, x.named_shape) for x in out]
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=3042'>3043</a> return tree_unflatten(out_tree(), out)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:479, in abstract_eval_fun(fun, debug_info, *avals, **params)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=477'>478</a> def abstract_eval_fun(fun, *avals, debug_info=None, **params):
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=478'>479</a>   _, avals_out, _ = trace_to_jaxpr_dynamic(
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=479'>480</a>       lu.wrap_init(fun, params), avals, debug_info)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=480'>481</a>   assert all(isinstance(aval, AbstractValue) for aval in avals_out)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=481'>482</a>   return avals_out
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/profiler.py:206, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/profiler.py?line=202'>203</a> @wraps(func)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/profiler.py?line=203'>204</a> def wrapper(*args, **kwargs):
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/profiler.py?line=204'>205</a>   with TraceAnnotation(name, **decorator_kwargs):
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/profiler.py?line=205'>206</a>     return func(*args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/profiler.py?line=206'>207</a>   return wrapper
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1666, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1663'>1664</a>   main.debug_info = debug_info  # type: ignore
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1664'>1665</a>   main.jaxpr_stack = ()  # type: ignore
# -> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1665'>1666</a>   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1666'>1667</a>     fun, main, in_avals, keep_inputs=keep_inputs)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1667'>1668</a>   del main, fun
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1668'>1669</a> return jaxpr, out_avals, consts
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1703, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1700'>1701</a> in_tracers = _avals_to_tracers(trace, in_avals)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1701'>1702</a> in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1702'>1703</a> ans = fun.call_wrapped(*in_tracers_)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1703'>1704</a> out_tracers = map(trace.full_raise, ans)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1704'>1705</a> jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py:166, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=162'>163</a> gen = gen_static_args = out_store = None
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=164'>165</a> try:
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=165'>166</a>   ans = self.f(*args, **dict(self.params, **kwargs))
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=166'>167</a> except:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=167'>168</a>   # Some transformations yield from inside context managers, so we have to
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=168'>169</a>   # interrupt them before reraising the exception. Otherwise they will only
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=169'>170</a>   # get garbage-collected at some later time, running their cleanup tasks
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=170'>171</a>   # only after this exception is handled, which can corrupt the global
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=171'>172</a>   # state.
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=172'>173</a>   while stack:
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py:166, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=162'>163</a> gen = gen_static_args = out_store = None
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=164'>165</a> try:
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=165'>166</a>   ans = self.f(*args, **dict(self.params, **kwargs))
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=166'>167</a> except:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=167'>168</a>   # Some transformations yield from inside context managers, so we have to
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=168'>169</a>   # interrupt them before reraising the exception. Otherwise they will only
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=169'>170</a>   # get garbage-collected at some later time, running their cleanup tasks
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=170'>171</a>   # only after this exception is handled, which can corrupt the global
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=171'>172</a>   # state.
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/linear_util.py?line=172'>173</a>   while stack:
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py:720, in Scope.param.<locals>.<lambda>(rng)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=713'>714</a> value = self.get_variable('params', name)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=714'>715</a> # Validate that the shape of the init_fn output is the same as the shape
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=715'>716</a> # of the existing parameter. This is to make sure that the hparams set up
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=716'>717</a> # in a Flax Module match the shapes coming in during apply, and if not,
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=717'>718</a> # catch it with an error message.
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=718'>719</a> # NOTE: We could consider moving this to `self.`
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=719'>720</a> abs_value = jax.eval_shape(lambda rng: init_fn(rng, *init_args), abs_rng)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=720'>721</a> abs_value_flat = jax.tree_leaves(abs_value)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/flax/core/scope.py?line=721'>722</a> value_flat = jax.tree_leaves(value)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/nn/initializers.py:148, in variance_scaling.<locals>.init(key, shape, dtype)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/nn/initializers.py?line=144'>145</a> if jnp.issubdtype(dtype, jnp.floating):
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/nn/initializers.py?line=145'>146</a>   # constant is stddev of standard normal truncated to (-2, 2)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/nn/initializers.py?line=146'>147</a>   stddev = jnp.sqrt(variance) / jnp.array(.87962566103423978, dtype)
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/nn/initializers.py?line=147'>148</a>   return random.truncated_normal(key, -2, 2, shape, dtype) * stddev
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/nn/initializers.py?line=148'>149</a> else:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/nn/initializers.py?line=149'>150</a>   # constant is stddev of complex standard normal truncated to 2
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/nn/initializers.py?line=150'>151</a>   stddev = jnp.sqrt(variance) / jnp.array(.95311164380491208, dtype)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/random.py:651, in truncated_normal(key, lower, upper, shape, dtype)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/random.py?line=648'>649</a> if shape is not None:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/random.py?line=649'>650</a>   shape = core.as_named_shape(shape)
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/random.py?line=650'>651</a> return _truncated_normal(key, lower, upper, shape, dtype)
#
#     [... skipping hidden 1 frame]
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py:427, in _cpp_jit.<locals>.cache_miss(*args, **kwargs)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=424'>425</a>   _check_arg(arg)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=425'>426</a> flat_fun, out_tree = flatten_fun(closed_fun, in_tree)
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=426'>427</a> out_flat = xla.xla_call(
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=427'>428</a>     flat_fun, *args_flat,
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=428'>429</a>     device=device, backend=backend, name=flat_fun.__name__,
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=429'>430</a>     donated_invars=donated_invars, inline=inline)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=430'>431</a> out_pytree_def = out_tree()
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/_src/api.py?line=431'>432</a> out = tree_unflatten(out_pytree_def, out_flat)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py:1690, in CallPrimitive.bind(self, fun, *args, **params)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=1688'>1689</a> def bind(self, fun, *args, **params):
# -> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=1689'>1690</a>   return call_bind(self, fun, *args, **params)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py:1702, in call_bind(primitive, fun, *args, **params)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=1698'>1699</a> fun, env_trace_todo = process_env_traces_call(
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=1699'>1700</a>     fun, primitive, top_trace and top_trace.level, tuple(params.items()))
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=1700'>1701</a> tracers = map(top_trace.full_raise, args)
# -> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=1701'>1702</a> outs = top_trace.process_call(primitive, fun, tracers, params)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=1702'>1703</a> return map(full_lower, apply_todos(env_trace_todo(), outs))
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1472, in DynamicJaxprTrace.process_call(self, call_primitive, f, tracers, params)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1468'>1469</a>   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1469'>1470</a>     f, self.main, in_avals, keep_inputs=keep_inputs)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1470'>1471</a> if params.get('inline', False):
# -> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1471'>1472</a>   return core.eval_jaxpr(jaxpr, consts, *dim_tracers, *tracers)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1472'>1473</a> source_info = source_info_util.current()
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1473'>1474</a> env = {v: t for v, t in zip((*jaxpr.constvars, *jaxpr.invars),
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1474'>1475</a>                             (*consts, *dim_tracers, *tracers))
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1475'>1476</a>        if isinstance(t, Tracer)}
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py:337, in eval_jaxpr(jaxpr, consts, *args)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=334'>335</a> subfuns, bind_params = eqn.primitive.get_bind_params(eqn.params)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=335'>336</a> with source_info_util.user_context(eqn.source_info.traceback):
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=336'>337</a>   ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=337'>338</a> if eqn.primitive.multiple_results:
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=338'>339</a>   map(write, eqn.outvars, ans)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py:279, in Primitive.bind(self, *args, **params)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=275'>276</a> def bind(self, *args, **params):
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=276'>277</a>   assert (not config.jax_enable_checks or
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=277'>278</a>           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=278'>279</a>   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py:282, in Primitive.bind_with_trace(self, trace, args, params)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=280'>281</a> def bind_with_trace(self, trace, args, params):
# --> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=281'>282</a>   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/core.py?line=282'>283</a>   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1450, in DynamicJaxprTrace.process_primitive(self, primitive, tracers, params)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1447'>1448</a> if primitive in custom_staging_rules:
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1448'>1449</a>   return custom_staging_rules[primitive](self, *tracers, **params)
# -> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1449'>1450</a> return self.default_process_primitive(primitive, tracers, params)
#
# File ~/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py:1462, in DynamicJaxprTrace.default_process_primitive(self, primitive, tracers, params)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1459'>1460</a> eqn = new_jaxpr_eqn(invars, outvars, primitive, params, source_info)
#    <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1460'>1461</a> self.frame.eqns.append(eqn)
# -> <a href='file:///home/gary/mambaforge3/envs/flashlight/lib/python3.10/site-packages/jax/interpreters/partial_eval.py?line=1461'>1462</a> return out_tracers if primitive.multiple_results else out_tracers.pop()
#
# KeyboardInterrupt:

# %%
u_approx = jax.vmap(lambda params, ur : model().apply(params, ur, method=VAE.decode), in_axes=(None,0))(params, urs.y.T)

# %%
fig, ax = plt.subplots()
im = ax.imshow(u_approx.T, aspect='auto', cmap='jet')
cb = fig.colorbar(im)

# %%
fig, ax = plt.subplots()
im = ax.imshow(u_ref[0:150].T, aspect='auto', cmap='jet', vmin=1, vmax=2)
cb = fig.colorbar(im)
